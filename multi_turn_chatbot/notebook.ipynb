# %%
! pip install -r requirements.txt

# %% [markdown]
# # Simple Multi-Modal chatbot
#
# This runs through an example of a multi-modal chatbot. Follow in the [application.py] file for specific implementation.

# %%
from application import application as multi_modal_chatbot

# %%
app = multi_modal_chatbot()

# %%
app.visualize(include_conditions=True)

# %%
action, result, state = app.run(halt_after=["response"], inputs={"prompt" : "who is Aaron Burr"})
print(state)
# Out:
# {'chat_history': [{'role': 'user', 'content': 'who is Aaron Burr', 'type': 'text'}, {'content': 'Aaron Burr was an American politician and lawyer who served as the third Vice President of the United States under President Thomas Jefferson from 1801 to 1805. He is perhaps best known for killing Alexander Hamilton in a famous duel in 1804. Burr also had a controversial political career, including his involvement in the Burr Conspiracy, a failed plot to create a separate nation in the western United States.', 'type': 'text', 'role': 'assistant'}], '__SEQUENCE_ID': 5, 'prompt': 'who is Aaron Burr', '__PRIOR_STEP': 'response', 'has_openai_key': True, 'safe': True, 'mode': 'answer_question', 'response': {'content': 'Aaron Burr was an American politician and lawyer who served as the third Vice President of the United States under President Thomas Jefferson from 1801 to 1805. He is perhaps best known for killing Alexander Hamilton in a famous duel in 1804. Burr also had a controversial political career, including his involvement in the Burr Conspiracy, a failed plot to create a separate nation in the western United States.', 'type': 'text', 'role': 'assistant'}}

# %% [markdown]
# # Viewing in UI
#
# The following cell gives you a link to the prior run in the UI. If you have not yet, run `burr` in your terminal to start the local tracking server.

# %%
from IPython.display import Markdown
url = f"[Link to UI](http://localhost:7241/project/demo_chatbot/{app.uid})"
Markdown(url)
# Out:
# [Link to UI](http://localhost:7241/project/demo_chatbot/8a2c0d98-b4ba-4c6f-a2d3-92e3b08eb930)
